# %% [markdown]
# Importing libreries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# Distribution Plot for Numerical data

# %%
sns.displot(df['Age'], kde = True)

# %%
sns.distplot(df['Age'], kde = True,hist = True, rug= True)
# Out:
# /tmp/ipython-input-4236009162.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde = True,hist = True, rug= True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'], kde = True, bins=40)
# Out:
# /tmp/ipython-input-813903979.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde = True, bins=40)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'], kde = True,hist = True, rug= True,bins=50)
# Out:
# /tmp/ipython-input-3188653524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], kde = True,hist = True, rug= True,bins=50)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'], kde = True,hist = True, rug= True,bins=50)
# Out:
# /tmp/ipython-input-2345125489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], kde = True,hist = True, rug= True,bins=50)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['FastingBS'], kde = True,hist = True, rug= True,bins=40)
# Out:
# /tmp/ipython-input-900734831.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'], kde = True,hist = True, rug= True,bins=40)
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'], kde = True,hist = True, rug= True,bins=50)
# Out:
# /tmp/ipython-input-1764232619.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'], kde = True,hist = True, rug= True,bins=50)
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %% [markdown]
# Pie chart for Categorical Data

# %%
df.groupby('Sex').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ExerciseAngina').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %% [markdown]
# Violin Plot To take Understanding of the Distribution

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(y=df['Sex'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y=df['RestingECG'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingECG'>

# %%
sns.violinplot(y=df['Cholesterol'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(y=df['ExerciseAngina'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ExerciseAngina'>

# %%
sns.violinplot(y=df['ChestPainType'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ChestPainType'>

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# Correlation between columns by heat maps

# %%
cols=['Age','RetingBP','Colestrol','FastingBS','MaxHR','OLdpeak','HeartDisease']

# %%
Numeric_df = df.select_dtypes(include='number')
sns.heatmap(Numeric_df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Joint point For taking Individual Correlation

# %%
sns.jointplot(x='Age',y='MaxHR',data=df)

# %%
sns.jointplot(x='Age',y='Age',data=df,kind='hex')

# %%
sns.jointplot(x='Age',y='Cholesterol',data=df,kind='reg')

# %%
sns.jointplot(x='HeartDisease',y='Cholesterol',data=df,kind='hex') # NO correlation

# %%
sns.jointplot(x='FastingBS',y='Cholesterol',data=df,kind='reg')

# %% [markdown]
# Pair Plot To take all Visual together

# %%
cols
# Out:
# ['Age',
#  'RetingBP',
#  'Colestrol',
#  'FastingBS',
#  'MaxHR',
#  'OLdpeak',
#  'HeartDisease']

# %%
sns.pairplot(df)
